# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = np.random.rand(100)
y_data = x_data*3.8 + 0.8

k = tf.Variable(0.)
b = tf.Variable(0.)
y = x_data*k + b
loss = tf.reduce_mean(tf.square(y - y_data))
train = tf.train.GradientDescentOptimizer(0.2).minimize(loss)
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for i in range(401):
        sess.run(train)
        if i%25 == 0:
            print(i ,sess.run([k,b]))
    plt.figure()
    plt.scatter(x_data,y_data)
    plt.show()
# Out:
# 0 [0.653157, 1.0648195]
# 25 [2.517865, 1.4746212]
# 50 [3.1612694, 1.1360809]
# 75 [3.4817994, 0.9674277]
# 100 [3.6414795, 0.88340867]
# 125 [3.7210286, 0.84155244]
# 150 [3.7606583, 0.82070047]
# 175 [3.7804005, 0.81031257]
# 200 [3.790236, 0.8051376]
# 225 [3.7951365, 0.80255914]
# 250 [3.797577, 0.8012749]
# 275 [3.7987928, 0.80063516]
# 300 [3.7993984, 0.80031645]
# 325 [3.7997005, 0.8001576]
# 350 [3.799851, 0.8000785]
# 375 [3.7999258, 0.80003905]
# 400 [3.7999628, 0.80001956]
